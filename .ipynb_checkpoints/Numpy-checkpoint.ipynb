# %%
import math

# %%
math.sqrt(5)**2
# Out:
# 5.000000000000001

# %%
# !pip install access
# Out:
# ...
# DEPRECATION: Loading egg at c:\users\admin\anaconda3\lib\site-packages\sensor-0.0.1-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..

# %%
import access

# %%
import pandas
import matplotlib
import seaborn
import numpy
import plotly

# %%
import math

# %%
from myFun import myFun
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from myFun import myFun
#
# ModuleNotFoundError: No module named 'myFun'

# %%
import myFun
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import myFun
#
# ModuleNotFoundError: No module named 'myFun'

# %%
myFun.
