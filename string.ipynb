# %%
x = ["a","b","c","d","e"]
y = 0 
for i in x:
    y =  y + len(i)
    
print(y)
# Out:
# 5

# %%
len(x)
# Out:
# 5

# %%
fruits = ["apple", "banana", "cherry"]
total_length = 0
for fruit in fruits:
    total_length += len(fruit)
print("Total length of characters:", total_length)
# Out:
# Total length of characters: 17
